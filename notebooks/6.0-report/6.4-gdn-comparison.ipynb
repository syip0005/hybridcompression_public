# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os.path as osp
import sys


def add_path(path):
    if path not in sys.path:
        sys.path.insert(0, path)


this_dir = osp.dirname('../../train.py')

lib_path = osp.join(this_dir, 'lib')
add_path(lib_path)

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import image
import pandas as pd
import time

# %%
import torch
from torch import nn
from utils.dataloader import CERN_Dataset_V3, UMASS_Dataset_V2, DRED_Dataset
from torch.utils.data import DataLoader
from models.models import HAE, AE, SCSAE
from models import gdn

# %%
hae_test_set = DRED_Dataset(train = True, no_rows = 30, wide_freq = 30, reshape_factor = 1, mode = 'cnn')
hae_loader = DataLoader(hae_test_set, batch_size = 1)
# Out:
# DRED processed.

# %%
len(hae_test_set.dred_data)
# Out:
# 5760

# %%
fig, ax = plt.subplots()
h = ax.imshow(hae_test_set.dred_data[373].squeeze(0), cmap = 'Blues')
fig.colorbar(h)
ax.set_title('DRED Example')
plt.savefig('dred_example.png', bbox_inches='tight')
plt.show()

# %%
img = image.imread('kodim09.png')
img = np.mean(img, axis = 2)

# %%
fig, ax = plt.subplots()
x = 700
y = 50
subimg = img[x:x+30, y:y+30]
subimg = (subimg - np.min(subimg)) / (np.max(subimg) - np.min(subimg))
h = ax.imshow(subimg, cmap='Blues')
ax.set_title('Kodak Example')
fig.colorbar(h)
plt.savefig('kodak_example.png', bbox_inches='tight')
plt.show()

# %%
plt.imshow(img)
